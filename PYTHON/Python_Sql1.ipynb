# %%
import mysql.connector


cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='Northwind')

print(cnx)

# %%
#EJERCICIO1: MOSTRAR BBDD QUE TENEMOS EN EL SERVIDOR

import mysql.connector

mydb = mysql.connector.connect(
                  user='root', password='AlumnaAdalab',
                  host='127.0.0.1',
                  database='Northwind')

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('leccion-1-sql',)
# ('leccion-10-sql',)
# ('leccion-11-sql',)
# ('leccion-12-sql',)
# ('leccion-13-sql',)
# ('leccion-14-sql',)
# ('leccion-2-sql',)
# ('leccion-3-sql',)
# ('leccion-4-sql',)
# ('leccion-5-sql',)
# ('leccion-6-sql',)
# ('leccion-7-sql',)
# ('leccion-8-sql',)
# ('leccion-9-sql',)
# ('mysql',)
# ('northwind',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('tienda',)
# ('world',)
# ('zapatitos',)

# %%
#EJERCICIO 2: MOSTRAR EL NOMBRE DE LAS TABLAS DE LA BBDD EN UNA LISTA

mycursor.execute("SHOW TABLES")

tablas = []
    
for x in mycursor:
    tablas.append(x)
    
print(tablas)
# Out:
# [('categories',), ('customer_customer_demo',), ('customer_demographics',), ('customers',), ('employee_territories',), ('employees',), ('order_details',), ('orders',), ('products',), ('region',), ('shippers',), ('suppliers',), ('territories',)]

# %%
#EJERCICIO 3: MOSTRAR COLUMNAS QUE TIENE CADA UNA DE LAS TABLAS. 


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="AlumnaAdalab",
  database="INFORMATION_SCHEMA"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT COLUMN_NAME FROM COLUMNS WHERE TABLE_SCHEMA = 'Northwind'")


columnas = []
for x in mycursor:
   columnas.extend(x)
  
print(columnas)
# Out:
# ['category_id', 'category_name', 'description', 'picture', 'customer_id', 'customertype_id', 'customer_desc', 'customer_type_id', 'address', 'city', 'company_name', 'contact_name', 'contact_title', 'country', 'customer_id', 'fax', 'phone', 'postal_code', 'region', 'employee_id', 'territory_id', 'address', 'birth_date', 'city', 'country', 'employee_id', 'extension', 'first_name', 'hire_date', 'home_phone', 'last_name', 'notes', 'photo', 'photo_path', 'postal_code', 'region', 'reports_to', 'title', 'title_of_courtesy', 'discount', 'order_id', 'product_id', 'quantity', 'unit_price', 'customer_id', 'employee_id', 'freight', 'order_date', 'order_id', 'required_date', 'ship_address', 'ship_city', 'ship_country', 'ship_name', 'ship_postal_code', 'ship_region', 'ship_via', 'shipped_date', 'category_id', 'discontinued', 'product_id', 'product_name', 'quantity_per_unit', 'reorder_level', 'supplier_id', 'unit_price', 'units_in_stock', 'units_on_order', 'region_description', 'region_id', 'compan
# ...

# %%
#EJERCICIO 4: QUERIES FACILITAS

    #Extraed el primer pedido donde se ha gastado más. Devolved el id del pedido y la cantidad gastada.


mydb = mysql.connector.connect(
                  user='root', password='AlumnaAdalab',
                  host='127.0.0.1',
                  database='Northwind')

mycursor = mydb.cursor()

mycursor.execute("SELECT order_id, MAX(unit_price * quantity) AS Cantidad_Gastada FROM order_details")

for x in mycursor:
    print(x)
# Out:
# (10248, 15810.0)

# %%
    # Devuelve la misma query que en el anterior ejercicio, pero en este caso devuelve todos los resultados.

mydb = mysql.connector.connect(
                  user='root', password='AlumnaAdalab',
                  host='127.0.0.1',
                  database='Northwind')

mycursor = mydb.cursor()

mycursor.execute("SELECT order_id, MAX(unit_price * quantity) AS Cantidad_Gastada FROM order_details GROUP BY order_id ORDER BY Cantidad_gastada DESC")

for x in mycursor:
 print(x)
# Out:
# (10865, 15810.0)
# (10981, 15810.0)
# (10353, 10540.0)
# (10417, 10540.0)
# (10889, 10540.0)
# (10424, 10329.2)
# (10897, 9903.2)
# (10372, 8432.0)
# (10540, 7905.0)
# (10816, 7905.0)
# (10817, 7905.0)
# (10912, 7427.400000000001)
# (11030, 7427.400000000001)
# (11032, 6587.5)
# (10776, 6360.0)
# (10479, 6324.0)
# (10993, 6189.5)
# (11017, 6050.0)
# (10515, 5268.0)
# (10691, 4951.6)
# (10687, 4850.0)
# (10510, 4456.4400000000005)
# (10666, 4456.4400000000005)
# (11072, 4322.5)
# (10329, 4216.0)
# (10351, 4216.0)
# (10953, 4050.0)
# (10518, 3952.5)
# (10616, 3952.5)
# (10672, 3952.5)
# (10633, 3944.0)
# (10711, 3935.9999999999995)
# (10607, 3900.0)
# (10678, 3800.0)
# (10360, 3465.0)
# (10595, 3420.0)
# (10895, 3400.0)
# (11008, 3192.0)
# (10514, 3159.0)
# (10634, 3125.0)
# (10854, 3100.0)
# (10267, 3080.0)
# (10430, 3080.0)
# (11064, 3003.0)
# (10893, 2970.96)
# (10949, 2958.0)
# (10324, 2808.0)
# (10524, 2760.0)
# (10316, 2758.0)
# (10841, 2750.0)
# (10688, 2736.0)
# ...

# %%
    # Extraed el números de pedidos que se hayan hecho por dia. Devuelve los resultados en una dataframe.

import mysql.connector
import pandas as pd


cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

print(cnx)
mycursor = cnx.cursor()
mycursor.execute("SELECT COUNT(order_id), DAY(order_date), MONTH(order_date), YEAR(order_date) FROM orders")
myresult = mycursor.fetchall()

df = pd.DataFrame(myresult, columns = ['Cantidad de Pedidos', 'Fecha'])
print(df)


# Tengo problemas con el módulo de pandas. Por eso da error.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\arian\Desktop\PythonJupyter\Python_Sql1.ipynb Celda 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/arian/Desktop/PythonJupyter/Python_Sql1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Extraed el números de pedidos que se hayan hecho por dia. Devuelve los resultados en una dataframe.
#       <a href='vscode-notebook-cell:/c%3A/Users/arian/Desktop/PythonJupyter/Python_Sql1.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> import mysql.connector
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arian/Desktop/PythonJupyter/Python_Sql1.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/arian/Desktop/PythonJupyter/Python_Sql1.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
# ...

# %%
    #Extraer los pedidos hechos por "Nancy Daviolo". Tendréis que hacer una subquery.

mydb = mysql.connector.connect(
                  user='root', password='AlumnaAdalab',
                  host='127.0.0.1',
                  database='Northwind')

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM orders WHERE employee_id IN (SELECT employee_id FROM employees WHERE first_name = 'Nancy' AND last_name = 'Davolio')")


for x in mycursor:
 print(x)
# Out:
# (10258, 'ERNSH', 1, datetime.datetime(1996, 7, 17, 0, 0), datetime.datetime(1996, 8, 14, 0, 0), datetime.datetime(1996, 7, 23, 0, 0), 1, 140.51, 'Ernst Handel', 'Kirchgasse 6', 'Graz', '', '8010', 'Austria')
# (10270, 'WARTH', 1, datetime.datetime(1996, 8, 1, 0, 0), datetime.datetime(1996, 8, 29, 0, 0), datetime.datetime(1996, 8, 2, 0, 0), 1, 136.54, 'Wartian Herkku', 'Torikatu 38', 'Oulu', '', '90110', 'Finland')
# (10275, 'MAGAA', 1, datetime.datetime(1996, 8, 7, 0, 0), datetime.datetime(1996, 9, 4, 0, 0), datetime.datetime(1996, 8, 9, 0, 0), 1, 26.93, 'Magazzini Alimentari Riuniti', 'Via Ludovico il Moro 22', 'Bergamo', '', '24100', 'Italy')
# (10285, 'QUICK', 1, datetime.datetime(1996, 8, 20, 0, 0), datetime.datetime(1996, 9, 17, 0, 0), datetime.datetime(1996, 8, 26, 0, 0), 2, 76.83, 'QUICK-Stop', 'Taucherstra�e 10', 'Cunewalde', '', '1307', 'Germany')
# ...

# %%
# EJERCICIO 5:

# Para finalizar el ejercicio, desconectad la conexión con el servidor.

cnx.close()
